# %% [markdown]
# # Part 3 - Text analysis and ethics

# %% [markdown]
# Computing PMI
#
# In this assessment you are tasked to discover strong associations between concepts in Airbnb reviews. The starter code we provide in this notebook is for orientation only. The below imports are enough to implement a valid answer.

# %% [markdown]
# ### Imports, data loading and helper functions

# %%
import pandas as pd
from nltk.tag import pos_tag
import re
from collections import defaultdict,Counter
from nltk.stem import WordNetLemmatizer
from datetime import datetime
from tqdm import tqdm
import numpy as np
import os
tqdm.pandas()

from nltk.corpus import stopwords
import string
from unicodedata import category

# %%
# nltk imports, note that these outputs may be different if you are using colab or local jupyter notebooks
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
# load stopwords
sw = set(stopwords.words('english'))

# %%
# if you use Google Colab:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
p = '/content/drive/MyDrive/coursework'
df = pd.read_csv(os.path.join(p,'reviews.csv'))
# deal with empty reviews
df.comments = df.comments.fillna('')

# %%
df.head(2)
# Out:
#    listing_id    id        date  reviewer_id reviewer_name  \
# 0        2818  1191  2009-03-30        10952           Lam
# 1        2818  1771  2009-04-24        12798         Alice
#
#                                             comments
# 0  Daniel is really cool. The place was nice and ...
# 1  Daniel is the most amazing host! His place is ...

# %%
df.shape
# Out:
# (452143, 6)

# %% [markdown]
# ### STEP1 - Process reviews

# %%
def process_reviews(df):
  """
  function perfroms tokenizaion, tagging and lower_tagging on the comments 
  
  args:df: reviews dataset
  
  returns: new data frame with three new columns tokenized,tagged and lower_tagged

  """
  
  df['tokenized']=df['comments'].apply(word_tokenize)
  df['tagged']= df['tokenized'].apply(pos_tag)
  df['lower_tagged']=df['tokenized'].apply(lambda x: [word.lower() for word in x]).apply(pos_tag)
  return df

# %%
#calling the function 
df = process_reviews(df)
df.head()
# Out:
#    listing_id    id        date  reviewer_id reviewer_name  \
# 0        2818  1191  2009-03-30        10952           Lam
# 1        2818  1771  2009-04-24        12798         Alice
# 2        2818  1989  2009-05-03        11869       Natalja
# 3        2818  2797  2009-05-18        14064       Enrique
# 4        2818  3151  2009-05-25        17977       Sherwin
#
#                                             comments  \
# 0  Daniel is really cool. The place was nice and ...
# 1  Daniel is the most amazing host! His place is ...
# 2  We had such a great time in Amsterdam. Daniel ...
# 3  Very professional operation. Room is very clea...
# 4  Daniel is highly recommended.  He provided all...
#
#                                            tokenized  \
# 0  [Daniel, is, really, cool, ., The, place, was,...
# 1  [Daniel, is, the, most, amazing, host, !, His,...
# 2  [We, had, such, a, great, time, in, Amsterdam,...
# 3  [Very, professional, operation, ., Room, is, v...
# 4  [Daniel, is, highly, recommended, ., He, provi...
#
#                                               tagged  \
# 0  [(Daniel, NNP), (is, VBZ), (really, RB), (cool...
# 1  [(Daniel, NNP), (is, VBZ), (the, DT), (most, R...
# 2  [(We, PRP), (had, VBD), (such, JJ), (a, DT), (...
# 3  [(Very, RB), (professional, JJ), (operation, N...
# 4  [(Daniel, NNP), (is, VBZ), (highly, RB), (reco...
#
#                                         lower_tagged
# 0  [(daniel, NN), (is, VBZ), (really, RB), (cool,...
# 1  [(daniel, NN), (is, VBZ), (the, DT), (most, RB...
# 2  [(we, PRP), (had, VBD), (such, JJ), (a, DT), (...
# 3  [(very, RB), (professional, JJ), (operation, N...
# 4  [(daniel, NN), (is, VBZ), (highly, RB), (recom...

# %% [markdown]
# ### STEP2- Create a vocabulary

# %%
def get_vocab(df):
 """
 Creates the vocabulary of center and context words 
  args:
      reviews dataset 
  Returns: 
       Two lists cont_vocab, cent_vocab -which contains most common nouns,verbs or adjective 
 """ 
 lower=[]
 for row in df['lower_tagged']:                    #Iterating rows in the lower_tagged column
   for word,pos in row:
      tagged_word = (word, pos)
      lower.append(tagged_word)
 center=[word for(word,pos) in lower if pos[:1]=='N']  # select words that are nouns 
 context=[word for(word,pos) in lower if pos[:1]=='V' or pos[:1]=='J'] #select words that verbs/adjectives
 freq_noun=Counter(center)
 center_words=freq_noun.most_common(1000)            # select most common nouns 
 freq_verb=Counter(context)
 context_words=freq_verb.most_common(1000)           # select most common verbs/adjectives 
 cent_vocab=[word for (word,val) in center_words]
 cont_vocab=[word for (word,val) in context_words]
 return cent_vocab, cont_vocab

# %%
cent_vocab, cont_vocab= get_vocab(df)
get_vocab(df)
# Out:
# (['place',
#   'apartment',
#   'location',
#   'amsterdam',
#   'i',
#   'host',
#   'stay',
#   'everything',
#   'city',
#   'room',
#   'time',
#   'house',
#   'area',
#   'home',
#   'center',
#   'très',
#   'restaurants',
#   '’',
#   'tram',
#   'centre',
#   'station',
#   'minutes',
#   'walk',
#   'bed',
#   'neighborhood',
#   'space',
#   'experience',
#   'thanks',
#   'hosts',
#   'à',
#   'thank',
#   'bien',
#   'la',
#   'communication',
#   'day',
#   'distance',
#   'kind',
#   'y',
#   'bathroom',
#   'days',
#   'kitchen',
#   'trip',
#   'et',
#   'lot',
#   'night',
#   'breakfast',
#   'sehr',
#   'arrival',
#   'e',
#   'people',
#   'airbnb',
#   'places',
#   'tips',
#   'bus',
#   'street',
#   'lots',
#   'boat',
#   'ist',
#   's',
#   'der',
#   'appartement',
#   'min',
#   'coffee',
#   'shops',
#   'muy',
#   'war',
#   'stairs',
#   'view',
#   'bit',
#   'transport',
#   'que',
#   'minute',
#   'bars',
#   'die',
#   'check',
#   'neighbourhood',
#   'questions',
#   'way',
#   'family',
#   'studio',
#   'anyone',
#   'things',
#   'es',
#   'access',
#   'dans',
#   'mit',
#   'man',
#   't',
#   'le',
#   'bike',
#   'weekend',
#   'town',
#   'canal',
#   'con',
#   'je',
#   'train',
#   'floor',
#   'food',
#   'appartment',
#   'information',
#   'morning',
#   'metro',
#   'pictures',
#   'amenities',
#   'couple',
#   'houseboat',
#   'stop',
#   'avons',
#   'shower',
#   'du',
#   'zu',
#   'bedroom',
#   'bikes',
#   'person',
#   'airport',
#   'wir',
#   'recommendations',
#   'part',
#   'door',
#   'transportation',
#   'supermarket',
#   'park',
#   'cafes',
#   'flat',
#   'balcony',
#   'friends',
#   'plenty',
#   'des',
#   'living',
#   'nights',
#   'garden',
#   'séjour',
#   'alles',
#   'corner',
#   'attractions',
#   'reservation',
#   'il',
#   'beds',
#   'photos',
#   'wine',
#   'è',
#   'calme',
#   'problem',
#   'situé',
#   'hospitality',
#   'perfect',
#   'casa',
#   'ride',
#   'friend',
#   'museums',
#   'cozy',
#   'water',
#   'visit',
#   'posting',
#   'terrace',
#   'spot',
#   'book',
#   'und',
#   'propre',
#   'pour',
#   'clean',
#   'para',
#   'mins',
#   'market',
#   'avec',
#   'les',
#   'pas',
#   'anything',
#   'di',
#   'centro',
#   'el',
#   'luggage',
#   'accommodation',
#   'fridge',
#   'thing',
#   'super',
#   'guests',
#   "l'appartement",
#   'light',
#   'heart',
#   'wohnung',
#   'son',
#   'het',
#   'windows',
#   'haben',
#   'hotel',
#   'logement',
#   'district',
#   'ferry',
#   'ein',
#   'molto',
#   'museum',
#   'grocery',
#   'l',
#   'au',
#   'comfy',
#   'da',
#   'suggestions',
#   'für',
#   'tourist',
#   'machine',
#   'wieder',
#   'vondelpark',
#   'touches',
#   'convenient',
#   'check-in',
#   'towels',
#   'week',
#   'ce',
#   'times',
#   'description',
#   'noise',
#   'rooms',
#   'hôte',
#   'lage',
#   'value',
#   'todo',
#   'bon',
#   'trams',
#   'flight',
#   'recommande',
#   'areas',
#   'eine',
#   'restaurant',
#   'welcome',
#   'wifi',
#   'bottle',
#   'building',
#   'touch',
#   'tea',
#   '%',
#   'advice',
#   'centraal',
#   'jordaan',
#   'van',
#   'foot',
#   'front',
#   'tout',
#   'end',
#   'stops',
#   'toilet',
#   'price',
#   'husband',
#   'tidy',
#   'right',
#   'canals',
#   'recommend',
#   'everyone',
#   'gut',
#   'proche',
#   'si',
#   'views',
#   'se',
#   'sur',
#   'cat',
#   'mais',
#   'par',
#   'd',
#   'qui',
#   'issue',
#   'b',
#   'helpful',
#   'von',
#   'supermarkets',
#   'était',
#   'air',
#   'privacy',
#   'fun',
#   'directions',
#   'tv',
#   'chambre',
#   'petit',
#   'das',
#   'store',
#   'keys',
#   'car',
#   'и',
#   'top',
#   'merci',
#   'pleasure',
#   'instructions',
#   'parfait',
#   'facilities',
#   'something',
#   'te',
#   'peter',
#   'kids',
#   'middle',
#   'ville',
#   'nothing',
#   'size',
#   'square',
#   'window',
#   'evening',
#   'welcoming',
#   'chez',
#   'details',
#   'issues',
#   'steps',
#   'messages',
#   'stores',
#   'bags',
#   'group',
#   'dem',
#   'property',
#   'weather',
#   'auf',
#   'gastgeber',
#   'waren',
#   'lo',
#   'life',
#   'shopping',
#   'bei',
#   'al',
#   'care',
#   'needs',
#   'close',
#   'che',
#   'side',
#   'centrum',
#   'hans',
#   'money',
#   'etc',
#   'shop',
#   'help',
#   'problems',
#   'sind',
#   'en',
#   'ha',
#   'hours',
#   'sauber',
#   'snacks',
#   'bar',
#   'table',
#   'base',
#   'travel',
#   'sights',
#   'guy',
#   'bedrooms',
#   'maison',
#   'por',
#   'choice',
#   'aufenthalt',
#   'service',
#   'del',
#   'couples',
#   'listing',
#   'accueil',
#   'é',
#   'vraiment',
#   'frank',
#   'als',
#   'excelente',
#   'dutch',
#   'spots',
#   'chance',
#   'children',
#   'wife',
#   'others',
#   'owner',
#   'cosy',
#   'streets',
#   'ci',
#   'im',
#   'drinks',
#   'maps',
#   "d'amsterdam",
#   'feel',
#   'como',
#   'tour',
#   'holiday',
#   'design',
#   'jan',
#   'transit',
#   'peu',
#   'moment',
#   'future',
#   'point',
#   'lugar',
#   'cute',
#   'anne',
#   'в',
#   'road',
#   'rest',
#   'line',
#   'beautiful',
#   'contact',
#   'cats',
#   'bath',
#   'use',
#   'map',
#   'dam',
#   'deck',
#   'walking',
#   'hour',
#   'zum',
#   'apt',
#   'sympathique',
#   'boyfriend',
#   'muito',
#   'block',
#   'work',
#   'bonus',
#   'pero',
#   'beer',
#   'attention',
#   'style',
#   'someone',
#   'year',
#   'options',
#   'daniel',
#   'schön',
#   'kommen',
#   'mark',
#   'roof',
#   'proximité',
#   'sympa',
#   'fait',
#   'gelegen',
#   'vacation',
#   'river',
#   'expectations',
#   'cerca',
#   'hope',
#   'o',
#   'dinner',
#   'girlfriend',
#   'anna',
#   'buena',
#   'transports',
#   'eingerichtet',
#   'kann',
#   'guest',
#   'process',
#   'note',
#   'sites',
#   'bnb',
#   'bustle',
#   'zona',
#   'chaleureux',
#   'number',
#   'empfehlen',
#   'described',
#   'parking',
#   'hostess',
#   'ad',
#   'einen',
#   'placé',
#   'flights',
#   'list',
#   'sin',
#   'minutos',
#   'daughter',
#   'perfekt',
#   'sofa',
#   'zimmer',
#   'check-out',
#   'question',
#   'flowers',
#   'ideal',
#   'voor',
#   'key',
#   'downtown',
#   'conforme',
#   'links',
#   'parks',
#   'markets',
#   'wohl',
#   'taxi',
#   'staff',
#   'équipé',
#   'ben',
#   'einer',
#   'sans',
#   'patio',
#   'recommandons',
#   'tourists',
#   'decor',
#   'zur',
#   'apartments',
#   'hand',
#   'amstel',
#   'ruhig',
#   'vivement',
#   'hustle',
#   'comfort',
#   'fue',
#   'juste',
#   'wie',
#   'cafés',
#   'sleep',
#   'case',
#   'tipps',
#   'stars',
#   'su',
#   'entrance',
#   'info',
#   'fact',
#   'comme',
#   'blocks',
#   'cafe',
#   'summer',
#   'laura',
#   'aux',
#   'unit',
#   'rooftop',
#   'stations',
#   'love',
#   'gefühlt',
#   'guide',
#   'lines',
#   'system',
#   'phone',
#   'parts',
#   'stuff',
#   'nicht',
#   'staircase',
#   'connection',
#   'zentrum',
#   'downstairs',
#   'ruben',
#   'grande',
#   'sun',
#   'fruit',
#   'boats',
#   'rob',
#   'minuten',
#   'schöne',
#   'zeit',
#   'locals',
#   'erreichen',
#   'buses',
#   'need',
#   'tolle',
#   'beaucoup',
#   'dryer',
#   'tiene',
#   'den',
#   'paul',
#   've',
#   'sink',
#   'gogh',
#   'sont',
#   'ma',
#   'loft',
#   'share',
#   'ons',
#   'mind',
#   'level',
#   'marcel',
#   'visiter',
#   'david',
#   'er',
#   'stadt',
#   'ground',
#   'été',
#   'barrio',
#   'journey',
#   'bread',
#   'one',
#   'quality',
#   'detail',
#   'responses',
#   'tres',
#   'era',
#   'terrasse',
#   'daan',
#   'café',
#   'vor',
#   'está',
#   'plus',
#   'faire',
#   'kommunikation',
#   'partner',
#   'schnell',
#   'gem',
#   'break',
#   'position',
#   'booking',
#   'pijp',
#   'furniture',
#   'на',
#   'floors',
#   'bonne',
#   'travelers',
#   'trouble',
#   'heel',
#   'nos',
#   'atmosphere',
#   'non',
#   'books',
#   'company',
#   'john',
#   'gastgeberin',
#   'dog',
#   'option',
#   'las',
#   'art',
#   'spacieux',
#   'dank',
#   'course',
#   'unterkunft',
#   'bas',
#   'fotos',
#   'start',
#   'com',
#   'meals',
#   'wouter',
#   'limpio',
#   'direkt',
#   'back',
#   'situation',
#   'cool',
#   '/',
#   'heating',
#   'posizione',
#   'op',
#   'adults',
#   'quelques',
#   'manuel',
#   'bakery',
#   'loads',
#   'clothes',
#   'cette',
#   'surprise',
#   'addition',
#   'thomas',
#   'maria',
#   'marc',
#   'internet',
#   'rai',
#   'warm',
#   'aanrader',
#   'rijksmuseum',
#   'tutto',
#   'owners',
#   'minuti',
#   'solo',
#   'centrale',
#   'rental',
#   'fleur',
#   'gute',
#   'departure',
#   'magnifique',
#   'tons',
#   'opportunity',
#   'emplacement',
#   'families',
#   'dass',
#   'baby',
#   'bel',
#   'pratique',
#   'disposition',
#   'business',
#   'sommes',
#   'cheese',
#   'response',
#   'feeling',
#   'fuß',
#   'nach',
#   'advices',
#   'jederzeit',
#   'karin',
#   'sure',
#   'anche',
#   'tranquilo',
#   'déjeuner',
#   'accommodations',
#   'même',
#   'reviews',
#   'dort',
#   'verblijf',
#   'locatie',
#   'informations',
#   'vélo',
#   'bem',
#   'jeroen',
#   'disponibile',
#   'arrivée',
#   'beers',
#   'doors',
#   'ton',
#   'nett',
#   'очень',
#   'mirjam',
#   'bicycles',
#   'years',
#   'tramway',
#   'zeer',
#   'items',
#   'los',
#   'martijn',
#   'drink',
#   'departamento',
#   'erik',
#   'couch',
#   'monique',
#   'roel',
#   'om',
#   'taste',
#   'm',
#   'einfach',
#   'conseils',
#   'activities',
#   'breeze',
#   'liegt',
#   'hay',
#   'bicycle',
#   'decoration',
#   'party',
#   'world',
#   'nice',
#   'inge',
#   'décoré',
#   'ciudad',
#   'idéalement',
#   'locations',
#   'immer',
#   'upstairs',
#   'belle',
#   'accomodation',
#   'eva',
#   'groceries',
#   'linda',
#   'commun',
#   'europe',
#   'erreichbar',
#   'hilfsbereit',
#   'nette',
#   '‘',
#   'apartamento',
#   'loin',
#   'interior',
#   'music',
#   'sono',
#   'della',
#   'vibe',
#   'sie',
#   'etwas',
#   'attentions',
#   'kim',
#   'bathrooms',
#   'deux',
#   'côté',
#   'oder',
#   'action',
#   'juice',
#   'alex',
#   'uns',
#   'cooking',
#   'braucht',
#   'hat',
#   'cleanliness',
#   'evenings',
#   'character',
#   'gemütlich',
#   'plan',
#   'bons',
#   'über',
#   'einem',
#   'cuisine',
#   'ed',
#   'points',
#   'michiel',
#   'easy',
#   'können',
#   'job',
#   'prima',
#   'jours',
#   'message',
#   'cómodo',
#   'bij',
#   'proximity',
#   'queries',
#   'jesse',
#   'hôtes',
#   'staying',
#   'og',
#   'plein',
#   'robert',
#   'recommendation',
#   'commerces',
#   'marieke',
#   'joost',
#   'calm',
#   'treats',
#   'nähe',
#   'habitación',
#   'charm',
#   'fonctionnel',
#   'persons',
#   'windmill',
#   '”',
#   'marion',
#   'gibt',
#   'ou',
#   'cycle',
#   'checkout',
#   'parfaitement',
#   'accueillante',
#   'matthijs',
#   'pieter',
#   'mattress',
#   'tage',
#   'ester',
#   'ellen',
#   'houses',
#   'experiences',
#   'vi',
#   'vom',
#   'glass',
#   'uber',
#   'guys',
#   'tim',
#   'george',
#   'treat',
#   'poco',
#   'hatten',
#   'beau',
#   'lumineux',
#   'picture',
#   'backyard',
#   'neighbors',
#   'henk',
#   'feels',
#   'kamer',
#   'città',
#   'cet',
#   'hausboot',
#   'martin',
#   'sister',
#   'equipment',
#   'joke',
#   'highlight',
#   'zeker',
#   'lit',
#   'sheets',
#   'pubs',
#   'deal',
#   'cookies',
#   'superb',
#   'traveler',
#   'suitcases',
#   'plaisir',
#   'buurt',
#   'personnes',
#   'couldn',
#   'stato',
#   'breakfasts',
#   'milk',
#   'facile',
#   'piedi',
#   'mornings',
#   'downside',
#   'martine',
#   'judith',
#   'duda',
#   'max',
#   'outside',
#   'simon',
#   'apartement',
#   'quartier',
#   'hair',
#   'environment',
#   'с',
#   'traffic',
#   'louise',
#   'rien',
#   'rick',
#   'ausgestattet',
#   'var',
#   'microwave',
#   'petra',
#   'pillows',
#   'justice',
#   'не',
#   'amount',
#   'suzanne',
#   'un',
#   'aber',
#   'ganz',
#   'willem',
#   'westerpark',
#   'kettle',
#   'andrea',
#   'trips',
#   'quarter',
#   'toys',
#   'stata',
#   'adresse',
#   'shampoo',
#   'maarten',
#   'empfangen',
#   'mike',
#   'schönes',
#   'excellent',
#   'order',
#   'gift',
#   'washer',
#   'johan',
#   'eggs',
#   'confortable',
#   'site',
#   'meal',
#   'peut',
#   'tom',
#   'confort',
#   'doorstep',
#   'accueillant',
#   '“',
#   'parents',
#   'essentials',
#   'küche',
#   'fan',
#   'située',
#   'interest',
#   'facilement',
#   'maker',
#   'star',
#   'près',
#   'sa',
#   'appliances',
#   'doubt',
#   "d'un",
#   'knowledge',
#   'surroundings',
#   'gentile',
#   'alla',
#   'cleaning',
#   'pieds',
#   'accueilli',
#   'boot',
#   'checkin',
#   'hesitation',
#   'passé',
#   'être',
#   'feet',
#   'relaxing',
#   'dat',
#   'fall',
#   'jo',
#   'cómoda',
#   'expérience',
#   'requests',
#   'viel',
#   'haus',
#   'aus',
#   'ook',
#   'laundry',
#   'mini',
#   '+',
#   'goed',
#   'fruits',
#   'gare',
#   'connections',
#   'aussi',
#   'chocolate',
#   'transporte',
#   'aller',
#   'vue',
#   'danke',
#   'bis',
#   'fragen',
#   'condition',
#   'jardin',
#   'plek',
#   'bart',
#   'weeks',
#   'winter',
#   'terms',
#   'aan',
#   'hostel',
#   'recommander',
#   'communications',
#   'estancia',
#   'michael',
#   'kleine',
#   'joris',
#   'buen',
#   'zijn',
#   'plans',
#   'afternoon',
#   'innenstadt',
#   'suite',
#   'péniche',
#   'kindness',
#   'request',
#   'cuyp',
#   'card',
#   'travellers',
#   'peace',
#   'все',
#   'petits',
#   'heartbeat',
#   'découvrir',
#   'edwin',
#   'quaint',
#   'walls',
#   'tub',
#   'perfecto'],
#  ['was',
#   'is',
#   'great',
#   'nice',
#   'had',
#   'clean',
#   'were',
#   'recommend',
#   'stay',
#   'are',
#   'good',
#   'perfect',
#   'i',
#   'comfortable',
#   'easy',
#   'have',
#   'be',
#   'quiet',
#   'helpful',
#   'beautiful',
#   'amazing',
#   'get',
#   'super',
#   'un',
#   "'s",
#   'amsterdam',
#   'located',
#   'wonderful',
#   'has',
#   'central',
#   'est',
#   '’',
#   'friendly',
#   'lovely',
#   'staying',
#   'need',
#   'made',
#   'nous',
#   'enjoyed',
#   'walking',
#   'spacious',
#   'flat',
#   'do',
#   'loved',
#   'little',
#   'needed',
#   'excellent',
#   'close',
#   'best',
#   'go',
#   'fantastic',
#   's',
#   'did',
#   'gave',
#   'come',
#   'walk',
#   'small',
#   'stayed',
#   'public',
#   'local',
#   'next',
#   'feel',
#   'many',
#   'short',
#   'recommended',
#   'welcoming',
#   'few',
#   'und',
#   'provided',
#   'felt',
#   'big',
#   'want',
#   'le',
#   'die',
#   'make',
#   'other',
#   'pour',
#   'much',
#   'cozy',
#   'quick',
#   'see',
#   'more',
#   'warm',
#   'arrived',
#   'cosy',
#   'been',
#   'first',
#   'left',
#   'met',
#   'tram',
#   'stylish',
#   'being',
#   'visit',
#   'sure',
#   'available',
#   'une',
#   'such',
#   'find',
#   'welcome',
#   'overall',
#   'een',
#   'equipped',
#   'looking',
#   'à',
#   'modern',
#   'take',
#   'accommodating',
#   'awesome',
#   'better',
#   'convenient',
#   'et',
#   'right',
#   'use',
#   'large',
#   'très',
#   'enjoy',
#   'check',
#   'got',
#   'una',
#   'able',
#   'steep',
#   'agréable',
#   'das',
#   'main',
#   'responsive',
#   'love',
#   'decorated',
#   'cool',
#   'uns',
#   'pleasant',
#   'went',
#   'es',
#   'meet',
#   'helped',
#   'private',
#   'les',
#   'having',
#   'sehr',
#   'full',
#   'canceled',
#   'help',
#   'automated',
#   'eat',
#   'flexible',
#   'welcomed',
#   'ist',
#   'happy',
#   'found',
#   'quartier',
#   'safe',
#   'going',
#   'wir',
#   'only',
#   "'re",
#   'getting',
#   'return',
#   'most',
#   'enough',
#   'own',
#   'nos',
#   'took',
#   'top',
#   'let',
#   'reach',
#   'expected',
#   'auch',
#   'thank',
#   'cute',
#   'explore',
#   'visiting',
#   'described',
#   'open',
#   'long',
#   'bright',
#   'accessible',
#   'know',
#   'appreciated',
#   'il',
#   'peaceful',
#   'wanted',
#   'situated',
#   'spent',
#   'late',
#   'takes',
#   'confortable',
#   'say',
#   'canal',
#   'leave',
#   'free',
#   'charming',
#   'am',
#   'light',
#   'old',
#   'fresh',
#   'new',
#   'give',
#   'exploring',
#   'ideal',
#   'thoughtful',
#   'vous',
#   'extra',
#   "'ve",
#   'offered',
#   'including',
#   'like',
#   'la',
#   'y',
#   'en',
#   'real',
#   'makes',
#   'making',
#   'huge',
#   'same',
#   'whole',
#   'useful',
#   'early',
#   'came',
#   'unique',
#   'hope',
#   'used',
#   'appartement',
#   'spend',
#   'nearby',
#   'unterkunft',
#   'busy',
#   'last',
#   'special',
#   'communicate',
#   'hidden',
#   'fine',
#   'comfy',
#   'walked',
#   'showed',
#   'hot',
#   'coming',
#   'looks',
#   'airbnb',
#   'gorgeous',
#   'sleep',
#   'pied',
#   'check-in',
#   'delicious',
#   'incredible',
#   'think',
#   'hospitable',
#   'due',
#   'several',
#   'asked',
#   'été',
#   'calm',
#   'live',
#   'interesting',
#   'bad',
#   'liked',
#   'du',
#   'prepared',
#   'second',
#   'furnished',
#   'den',
#   'worked',
#   'relax',
#   'residential',
#   'sweet',
#   'different',
#   'relaxing',
#   'respond',
#   'greeted',
#   'um',
#   'clear',
#   'shared',
#   'look',
#   'possible',
#   'für',
#   'fabulous',
#   'answered',
#   'less',
#   'narrow',
#   'does',
#   'séjour',
#   'passé',
#   'rent',
#   'que',
#   'attentive',
#   'traveling',
#   'brilliant',
#   'ich',
#   'el',
#   'walkable',
#   'simple',
#   'ask',
#   'enjoyable',
#   'des',
#   'aber',
#   'keep',
#   'responded',
#   'cold',
#   'wish',
#   'ready',
#   'allowed',
#   'high',
#   't',
#   'communicative',
#   'didn',
#   'red',
#   'checked',
#   'centraal',
#   'major',
#   'kept',
#   'logement',
#   'using',
#   "'m",
#   'stocked',
#   'booked',
#   'living',
#   'thought',
#   'sich',
#   'eine',
#   'disponible',
#   're',
#   'sont',
#   'se',
#   'cook',
#   'metro',
#   'answer',
#   'giving',
#   'notre',
#   'au',
#   'put',
#   'told',
#   'personal',
#   'nicht',
#   'waiting',
#   'slept',
#   'connected',
#   'pretty',
#   'try',
#   'said',
#   'travel',
#   'im',
#   'expect',
#   'adorable',
#   'gerne',
#   'typical',
#   'o',
#   'experience',
#   'given',
#   'offer',
#   'advertised',
#   'noisy',
#   'shower',
#   'si',
#   'entire',
#   'outside',
#   'fast',
#   'smooth',
#   'separate',
#   'downtown',
#   'qui',
#   'de',
#   'explained',
#   'e',
#   'set',
#   'gracious',
#   'generous',
#   'important',
#   'provide',
#   'providing',
#   'centre',
#   'looked',
#   'bigger',
#   'bring',
#   'wohnung',
#   'ride',
#   'stunning',
#   'dans',
#   'necessary',
#   'work',
#   'pas',
#   'sit',
#   'touristy',
#   'don',
#   'worth',
#   'het',
#   'hesitate',
#   "c'est",
#   'grand',
#   'taking',
#   'arrive',
#   'outstanding',
#   'handy',
#   'basic',
#   'single',
#   'nur',
#   'organized',
#   'muy',
#   'hard',
#   'designed',
#   'hear',
#   'checking',
#   'booking',
#   'difficult',
#   'included',
#   'show',
#   "l'appartement",
#   'ok',
#   'accurate',
#   'avec',
#   'sent',
#   'gives',
#   'ein',
#   'website',
#   'rented',
#   'dutch',
#   'albert',
#   'relaxed',
#   'travelling',
#   'contact',
#   'wait',
#   'shown',
#   'true',
#   'favorite',
#   'lo',
#   'young',
#   'authentic',
#   'ne',
#   'leaving',
#   '10-15',
#   'aware',
#   'bien',
#   'sunny',
#   'added',
#   'provides',
#   'sleeping',
#   'sitting',
#   'loud',
#   'working',
#   'goes',
#   'arranged',
#   'amable',
#   'watching',
#   'neat',
#   'wants',
#   'wirklich',
#   'auf',
#   'recomendable',
#   'choose',
#   'tiny',
#   'd',
#   'fun',
#   'quite',
#   'willing',
#   'hatten',
#   'spotless',
#   'received',
#   'ce',
#   'detailed',
#   'prompt',
#   'natural',
#   'done',
#   'ubicación',
#   'overlooking',
#   'watch',
#   'sur',
#   'appointed',
#   'al',
#   'casa',
#   'double',
#   '15-20',
#   'front',
#   'sparkling',
#   'zimmer',
#   'dam',
#   'suggest',
#   'chambre',
#   'direct',
#   'er',
#   'superb',
#   'accueil',
#   'longer',
#   'delayed',
#   'delightful',
#   'lucky',
#   'letting',
#   'alles',
#   'discover',
#   'tous',
#   'surrounding',
#   'heavy',
#   'buy',
#   'parking',
#   'general',
#   'pictured',
#   'tidy',
#   'functional',
#   'communicated',
#   'einen',
#   'bus',
#   'stop',
#   'drink',
#   'informative',
#   'offers',
#   'recommande',
#   'sharing',
#   'anne',
#   'visited',
#   'recommand',
#   'filled',
#   'start',
#   'talk',
#   'einem',
#   'para',
#   'würden',
#   'ont',
#   'freundlich',
#   'expensive',
#   'etc',
#   'near',
#   'las',
#   'thanks',
#   'mentioned',
#   'è',
#   'rental',
#   'helping',
#   'arriving',
#   'polite',
#   'consider',
#   'disappointed',
#   'pick',
#   'hang',
#   'roof',
#   'common',
#   'called',
#   'climb',
#   'feels',
#   'least',
#   'positive',
#   'renovated',
#   'couldn',
#   'plan',
#   'waited',
#   'seems',
#   'green',
#   'petite',
#   'regarding',
#   'gets',
#   'bed',
#   'outdoor',
#   'kitchen',
#   'tried',
#   'rooftop',
#   'non',
#   'sightseeing',
#   'cleaned',
#   'enjoying',
#   'll',
#   'seeing',
#   'reachable',
#   'terrific',
#   'surrounded',
#   'waren',
#   'tell',
#   'está',
#   'uma',
#   'closed',
#   'miss',
#   'merci',
#   'pleased',
#   'managed',
#   'greet',
#   'seen',
#   'niet',
#   'placed',
#   'comes',
#   'third',
#   'aux',
#   'complete',
#   'sie',
#   'drop',
#   'agradable',
#   'future',
#   'knew',
#   'saw',
#   'cooking',
#   'communicating',
#   'te',
#   'smaller',
#   'move',
#   'reached',
#   'trendy',
#   'suitable',
#   'mind',
#   'romantic',
#   'los',
#   'cafe',
#   'planning',
#   'unos',
#   'arrival',
#   'u',
#   'loft',
#   'absolute',
#   'appreciate',
#   'key',
#   'washing',
#   'von',
#   'exceptional',
#   'glad',
#   'sauber',
#   'taken',
#   'caring',
#   'lage',
#   'chill',
#   'di',
#   'op',
#   'carry',
#   'further',
#   'fit',
#   'memorable',
#   'chose',
#   'picked',
#   'dining',
#   'brought',
#   'seemed',
#   'frank',
#   'touristic',
#   'total',
#   'back',
#   'renting',
#   'idéal',
#   'bike',
#   'well-equipped',
#   'note',
#   'nuestra',
#   'lives',
#   'replied',
#   'rest',
#   'med',
#   'considering',
#   'works',
#   'surprised',
#   'needs',
#   'zentral',
#   'cheap',
#   'hosting',
#   'decent',
#   'exceeded',
#   'accommodate',
#   'traditional',
#   'easier',
#   'returning',
#   'dem',
#   'multiple',
#   'minuten',
#   'uncomplicated',
#   'wanting',
#   'der',
#   'diese',
#   'efficient',
#   'run',
#   'transport',
#   'finding',
#   'mention',
#   'zu',
#   'eating',
#   'kann',
#   '‘',
#   'deal',
#   'nicest',
#   'larger',
#   'uber',
#   'navigate',
#   'n',
#   'pay',
#   'wie',
#   'answering',
#   'ended',
#   'quirky',
#   'gut',
#   'various',
#   'lived',
#   'je',
#   'daily',
#   'mal',
#   'ten',
#   'bought',
#   'mais',
#   'understanding',
#   'eu',
#   'careful',
#   'ou',
#   'organised',
#   'catch',
#   'était',
#   'apartment',
#   'nearest',
#   'negative',
#   '5-10',
#   'responding',
#   'impeccable',
#   'imagine',
#   'recommending',
#   'doing',
#   'maintained',
#   'situé',
#   'alle',
#   'nespresso',
#   'ensure',
#   'reasonable',
#   'wasn',
#   'suited',
#   'practical',
#   'dirty',
#   'l',
#   'accommodated',
#   'served',
#   'satisfied',
#   'accomodating',
#   'petit',
#   'store',
#   'recomend',
#   'spectacular',
#   'konnten',
#   'reply',
#   'upstairs',
#   'очень',
#   'tal',
#   'van',
#   'crowded',
#   'erg',
#   'airy',
#   'bother',
#   'trying',
#   'equiped',
#   'offering',
#   'wake',
#   'transports',
#   'vondelpark',
#   'interior',
#   'helpfull',
#   'week-end',
#   'laid',
#   'cet',
#   'wifi',
#   'suggested',
#   'previous',
#   'call',
#   'professional',
#   'в',
#   'read',
#   'voor',
#   'normal',
#   'recommendable',
#   'reactive',
#   'todo',
#   'original',
#   'soft',
#   'park',
#   "s'est",
#   'missing',
#   'pu',
#   'straight',
#   'beat',
#   'uncomfortable',
#   'frühstück',
#   'lost',
#   'tolle',
#   'running',
#   'fue',
#   'historic',
#   'elle',
#   'allowing',
#   'grateful',
#   'required',
#   'luxurious',
#   'minor',
#   'leading',
#   "n'est",
#   'lit',
#   'prefer',
#   'famous',
#   'reccomend',
#   'heel',
#   'unsere',
#   'prepare',
#   'planned',
#   'noch',
#   'wrong',
#   'hôtes',
#   'toutes',
#   'experienced',
#   'feeling',
#   'fell',
#   've',
#   'train',
#   'hebben',
#   'stops',
#   'og',
#   'hausboot',
#   'popular',
#   'explain',
#   'haus',
#   'regret',
#   'meeting',
#   'round',
#   'par',
#   'reliable',
#   'accueillant',
#   'favourite',
#   'paid',
#   'endroit',
#   'ses',
#   'knowledgeable',
#   '/',
#   'wenn',
#   'presented',
#   'earlier',
#   'play',
#   'sind',
#   'alex',
#   'believe',
#   'turned',
#   'forget',
#   'additional',
#   'parfait',
#   'werden',
#   'trams',
#   'supplied',
#   'eric',
#   'c',
#   'tasty',
#   'older',
#   'inviting',
#   'started',
#   'vibrant',
#   'unseren',
#   'sized',
#   'esta',
#   'cual',
#   'affordable',
#   'low',
#   'please',
#   'apprécié',
#   'listed',
#   'unforgettable',
#   'heineken',
#   'interested',
#   'spending',
#   'con',
#   'por',
#   'unkompliziert',
#   'tight',
#   'solo',
#   'breakfast',
#   'decided',
#   'couple',
#   'gehad',
#   'appartment',
#   'nicer',
#   'vielen',
#   'jordaan',
#   'liegt',
#   'opened',
#   'ook',
#   'talking',
#   'avoid',
#   'missed',
#   'immer',
#   'unser',
#   'broken',
#   'sa',
#   'showing',
#   'om',
#   'check-out',
#   'cooked',
#   'bei',
#   'impressed',
#   'add',
#   'means',
#   'attic',
#   'tourist',
#   'seem',
#   'restaurant',
#   'leuke',
#   'strong',
#   'bon',
#   'prime',
#   'immaculate',
#   'allow',
#   '“',
#   'da',
#   'meant',
#   'scenic',
#   'enter',
#   'fixed',
#   'vraiment',
#   'prima',
#   'superbe',
#   'wished',
#   'place',
#   'anywhere',
#   'allem',
#   'guest',
#   'settled',
#   'hier',
#   'regular',
#   'wide',
#   'waking',
#   'lively',
#   'chez',
#   'magical',
#   'english',
#   'remember',
#   'cette',
#   'thin',
#   'helps',
#   'vélos',
#   'shopping',
#   'su',
#   '20-30',
#   'funny',
#   'end',
#   'gute',
#   'runs',
#   'emplacement',
#   'gare',
#   'quieter',
#   'chic',
#   'european',
#   'immediate',
#   'minute',
#   'hanging',
#   'complain',
#   'didnt',
#   'wurden',
#   'facing',
#   'proper',
#   'worry',
#   'ate',
#   'actual',
#   'réactive',
#   'very',
#   'won',
#   'roomy',
#   'dont',
#   'follow',
#   'deux',
#   'present',
#   'wouldn',
#   'tall',
#   'fab',
#   'contacted',
#   'goed',
#   'wat',
#   'numerous',
#   'says',
#   'habitación',
#   'knows',
#   'white',
#   '+',
#   'compared',
#   'heated',
#   'everyday',
#   'expecting',
#   'informed',
#   'complimentary',
#   'smart',
#   'não',
#   'center',
#   'locked',
#   'haben',
#   'genial',
#   'inner',
#   'allows',
#   'facile',
#   'gleich',
#   'changed',
#   'limited',
#   'abbiamo',
#   'fair',
#   'chat',
#   'particular',
#   'hoped',
#   'understand',
#   'tricky',
#   'tired',
#   'respectful',
#   'okay',
#   'returned',
#   'everywhere',
#   'ubicado',
#   'tucked',
#   'gracias',
#   'chilled',
#   'well-located',
#   'avant',
#   'based',
#   'cafes',
#   'silent',
#   'biking',
#   'agreed',
#   'considerate'])

# %% [markdown]
# ### STEP 3 Count co-occurrences between center and context words

# %%
def window_cooc(lst, coocs, cent_vocab, cont_vocab, window_size=5):
  """
  Creates a dictionary of dictionaries from center and context words 

  args:
      lst:List of tokens 
      coocs: co-occurrence matrix of centre and context words
      cent_vocab: list of center words
      cont_vocab: list of context words
      windows_size: size of the windows to search co-occurence
  Returns: 
      coocs:Count of co-occurence of centre and context words 
  """
  length = len(lst)
  # iterate through tokens in the lst
  for i, word in enumerate(lst):
    if word in cent_vocab:
      # when we found a center word, iterate through neighbours in radius 
      # of windows size (for example 5 words before and 5 words after)
      for j in range(max(i - window_size, 0), min(i + window_size, length)):
        # find context words in the window ignoring the center word
        if lst[j] in cont_vocab and j != i:
          # add a co-occurence case in the coocs dictionary
          coocs[word][lst[j]] = coocs[word].get(lst[j], 0) + 1


def get_coocs(df, cent_vocab, cont_vocab):

  coocs = {}
  # create an empty dictionary structure for a co-occurence matrix
  for word in cent_vocab:
    coocs[word] = {}
    for cont in cont_vocab:
      coocs[word][cont] = 0
  # iterate through the 'tokenized' column
  for row in df.tokenized:
    # make a list of lowered tokens
    lst = [word.lower() for word in row]
    # process the row and add all co-occurence case into the coocs dictionary
    window_cooc(row, coocs, cent_vocab, cont_vocab)
  return coocs

# %%
coocs = get_coocs(df, cent_vocab, cont_vocab)
list(coocs)[:2]
# Out:
# ['place', 'apartment']

# %% [markdown]
# ### STEP 4 Convert co-occurrence dictionary to 1000x1000 dataframe

# %%
def cooc_dict2df(coocs):
  """
     Function takes co-occurrence matrix from previous function and converts to a dataframe
     
     Args:
         coocs: co-occurrence matrix
     Returns:
          1000*1000 dataframe with rows and columns as centre,contex words 
  """
  coocdf = pd.DataFrame(coocs).fillna(0)
  return coocdf

# %%
coocdf = cooc_dict2df(coocs)
coocdf.head()
# Out:
#        place  apartment  location  amsterdam    i   host   stay  everything  \
# was    30764      35994     21164        376  872  37770  20085       13312
# is     44540      51985     36565        568  474  30776   9827        9839
# great  19706      14837     29575        256  222  23092  17109        2930
# nice   11634      10879      6376        173  191   7333   7040        1794
# had     1969       3099      1107        192  471   2094  17365        8026
#
#         city   room  ...  peace  все  petits  heartbeat  découvrir  edwin  \
# was     5990  17858  ...     38    0       0         24          0      0
# is     10461  18270  ...     65    0       0         14          0      4
# great   2968   3669  ...     15    0       0          4          0      0
# nice    1372   5328  ...     10    0       0          0          0      2
# had      918   1916  ...     13    0       0          2          0      0
#
#        quaint  walls  tub  perfecto
# was       275     57  139         0
# is        379     79  136         2
# great      45     16   68         0
# nice       39     11   57         0
# had        22     12   18         0
#
# [5 rows x 1000 columns]

# %%
coocdf.shape
# Out:
# (1000, 1000)

# %% [markdown]
# ### STEP 5 Raw co-occurrences to PMI scores
#
# What to implement: A function `cooc2pmi(df)` that takes as input the DataFrame generated in step 4, and returns a new DataFrame with the same rows and columns, but with PMI scores instead of raw co-occurrence counts.

# %%
def cooc2pmi(df):
  """
  args: 
     df: dataframe of co-occurrence dictionary from previous stage 
  return: dataframe 1000x1000 of center and context words with their
    pointwise mutual information 
  """
  # make an empty dataframe with the same structure as df
  pmidf = pd.DataFrame().reindex_like(df)
  # a sum of all rows and columns
  n = coocdf.sum().sum()
  # series with sums of rows and columns
  x_sum = coocdf.sum()
  y_sum = coocdf.sum(axis=1)
  # iterate through column names (center words) and row indexes (context words)
  for col in df.columns:
    for row in df.index:
      # calculate PMI
      p_i = x_sum[col] / n
      p_j = y_sum[row] / n
      p_ij = df[col][row]
      # to avoid division by zero or getting minus infinity, we will consider
      # pmi in such cases as -1
      if p_i == 0 or p_j == 0 or p_ij == 0:
        pmidf[col][row] = -1
      else:
        pmidf[col][row] = np.log10(p_ij / (p_i * p_j))
  return pmidf

# %%
pmidf = cooc2pmi(coocdf)
pmidf.head()
# Out:
#           place  apartment  location  amsterdam         i      host      stay  \
# was    7.380041   7.466215  7.345248   6.988108  7.123727  7.669588  7.299826
# is     7.499662   7.584776  7.541629   7.126182  6.817902  7.539567  6.948288
# great  7.569792   7.464526  7.873770   7.204355  6.912759  7.839098  7.613374
# nice   7.551398   7.540245  7.417869   7.244637  7.057915  7.551394  7.438197
# had    6.871689   7.086652  6.749243   7.381667  7.541677  7.098863  7.922074
#
#        everything      city      room  ...     peace  все  petits  heartbeat  \
# was      7.393922  7.058714  7.527057  ...  6.831484 -1.0    -1.0   6.859608
# is       7.221543  7.259773  7.495876  ...  7.023527 -1.0    -1.0   6.584438
# great    7.119742  7.136946  7.222967  ...  6.810987 -1.0    -1.0   6.464652
# nice     7.117172  7.012312  7.595459  ...  6.845371 -1.0    -1.0  -1.000000
# had      7.859623  6.929575  7.243065  ...  7.051089 -1.0    -1.0   6.465872
#
#        découvrir     edwin    quaint     walls       tub  perfecto
# was         -1.0 -1.000000  7.460358  7.011211  7.365401 -1.000000
# is          -1.0  7.482965  7.558577  7.111877  7.314838  5.517568
# great       -1.0 -1.000000  7.057433  6.842652  7.438091 -1.000000
# nice        -1.0  7.816692  7.205761  6.890400  7.571932 -1.000000
# had         -1.0 -1.000000  7.048893  7.019963  7.163104 -1.000000
#
# [5 rows x 1000 columns]

# %%
pmidf.shape
# Out:
# (1000, 1000)

# %% [markdown]
# ### 3.a6 Retrieve top-k context words, given a center word
#
# What to implement: A function `topk(df, center_word, N=10)` that takes as input: (1) the DataFrame generated in step 5, (2) a `center_word` (a string like `‘towels’`), and (3) an optional named argument called `N` with default value of 10; and returns a list of `N` strings, in order of their PMI score with the `center_word`. You do not need to handle cases for which the word `center_word` is not found in `df`.

# %%
def topk(df, center_word, N=10):
  """Get top N context words for a centerword from the PMI dataframe"""
  top_words = df[center_word].sort_values(ascending=False).index[:N].to_list()
  return top_words

# %%
topk(pmidf, 'coffee')
# Out:
# ['nespresso',
#  'complimentary',
#  'supplied',
#  'drink',
#  'delicious',
#  'including',
#  'stocked',
#  'fresh',
#  'breakfast',
#  'tasty']
